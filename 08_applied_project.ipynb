# %% [markdown]
# <div style="background: linear-gradient(135deg, #4B2E83 0%, #32006E 100%); padding: 40px 30px; border-radius: 15px; box-shadow: 0 8px 20px rgba(75,46,131,0.3);">
#   <img src="https://uw-s3-cdn.s3.us-west-2.amazonaws.com/wp-content/uploads/sites/230/2023/11/02134828/Signature_Left_Gold_RGB.png" alt="University of Washington" style="height: 80px; margin-bottom: 20px;">
#   <h1 style="color: #FFF; font-family: 'Encode Sans', 'Arial', sans-serif; font-weight: 700; font-size: 2.8em; margin: 20px 0 15px 0; text-shadow: 2px 2px 4px rgba(0,0,0,0.3);">Applied Project</h1>
#   <p style="color: #E8D3FF; font-family: 'Encode Sans', 'Arial', sans-serif; font-size: 1.3em; margin: 10px 0; font-weight: 300;">BDATA 412 — Advanced Data Visualization · Section 8</p>
#   <p style="color: #B7A6D5; font-family: 'Encode Sans', 'Arial', sans-serif; font-size: 1.1em; margin: 5px 0;">University of Washington</p>
# </div>
#
# <div style="background-color: #F5F5F5; padding: 15px 25px; border-left: 5px solid #4B2E83; border-radius: 5px; margin-top: 25px;">
#   <p style="font-size: 1.1em; color: #333; margin: 0;"><strong style="color: #4B2E83;">Open in Google Colab:</strong></p>
#   <p style="margin: 10px 0 5px 0;"><a target="_blank" href="https://colab.research.google.com/github/PedroBSB/BDATA412/blob/main/08_applied_project.ipynb"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab" style="vertical-align: middle;"/></a></p>
# </div>

# %% [markdown]
# <div style="background: linear-gradient(to right, #FFF8E1, #FFFEF7); padding: 20px 25px; border-radius: 10px; border: 2px solid #E8B923; margin: 30px 0;">
#   <h3 style="color: #4B2E83; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0; font-size: 1.3em;">Group Information</h3>
#   <div style="background-color: white; padding: 15px; border-radius: 5px; margin-top: 15px;">
#     <p style="margin: 10px 0; color: #333; font-size: 1.05em;"><strong style="color: #4B2E83;">Project Title:</strong> <span style="color: #666;">[Enter your project title]</span></p>
#     <hr style="border: none; border-top: 1px solid #E8E0F5; margin: 15px 0;">
#     <p style="margin: 10px 0; color: #333; font-size: 1.05em;"><strong style="color: #4B2E83;">Member 1 — Name:</strong> <span style="color: #666;">[Enter name]</span></p>
#     <p style="margin: 10px 0; color: #333; font-size: 1.05em;"><strong style="color: #4B2E83;">Member 1 — Student ID:</strong> <span style="color: #666;">[Enter student ID]</span></p>
#     <hr style="border: none; border-top: 1px solid #E8E0F5; margin: 15px 0;">
#     <p style="margin: 10px 0; color: #333; font-size: 1.05em;"><strong style="color: #4B2E83;">Member 2 — Name:</strong> <span style="color: #666;">[Enter name]</span></p>
#     <p style="margin: 10px 0; color: #333; font-size: 1.05em;"><strong style="color: #4B2E83;">Member 2 — Student ID:</strong> <span style="color: #666;">[Enter student ID]</span></p>
#     <hr style="border: none; border-top: 1px solid #E8E0F5; margin: 15px 0;">
#     <p style="margin: 10px 0; color: #333; font-size: 1.05em;"><strong style="color: #4B2E83;">Member 3 — Name:</strong> <span style="color: #666;">[Enter name]</span></p>
#     <p style="margin: 10px 0; color: #333; font-size: 1.05em;"><strong style="color: #4B2E83;">Member 3 — Student ID:</strong> <span style="color: #666;">[Enter student ID]</span></p>
#     <hr style="border: none; border-top: 1px solid #E8E0F5; margin: 15px 0;">
#     <p style="margin: 10px 0; color: #333; font-size: 1.05em;"><strong style="color: #4B2E83;">Member 4 — Name:</strong> <span style="color: #666;">[Enter name, or remove if not applicable]</span></p>
#     <p style="margin: 10px 0; color: #333; font-size: 1.05em;"><strong style="color: #4B2E83;">Member 4 — Student ID:</strong> <span style="color: #666;">[Enter student ID, or remove if not applicable]</span></p>
#     <hr style="border: none; border-top: 1px solid #E8E0F5; margin: 15px 0;">
#     <p style="margin: 10px 0; color: #333; font-size: 1.05em;"><strong style="color: #4B2E83;">Date:</strong> <span style="color: #666;">[Enter date]</span></p>
#   </div>
# </div>

# %% [markdown]
# <div style="background: linear-gradient(to right, #F7F4FB, #FFFFFF); padding: 25px; border-radius: 10px; border: 2px solid #E8E0F5; margin: 25px 0;">
#   <h2 style="color: #4B2E83; font-family: 'Encode Sans', 'Arial', sans-serif; font-weight: 700; border-bottom: 3px solid #4B2E83; padding-bottom: 10px;">Project Structure Guide</h2>
#   <p style="font-size: 1.05em; color: #555; line-height: 1.7; margin-bottom: 10px;">This notebook is organized into the following sections. Complete each part to build your final applied project.</p>
#   <ul style="font-size: 1.05em; line-height: 2; color: #333; list-style-type: none; padding-left: 0;"><li><strong>Part 1: Introduction & Research Question</strong><ul style='list-style-type: disc; margin-left: 30px;'><li>Problem Statement</li><li>Research Questions & Hypotheses</li><li>Motivation & Relevance</li></ul></li><li><strong>Part 2: Data Description & Preprocessing</strong><ul style='list-style-type: disc; margin-left: 30px;'><li>Data Loading & Inspection</li><li>Missing Value Treatment</li><li>Feature Engineering & Standardization</li></ul></li><li><strong>Part 3: Exploratory Data Analysis</strong><ul style='list-style-type: disc; margin-left: 30px;'><li>Descriptive Statistics</li><li>Distribution Plots</li><li>Correlation Heatmap</li></ul></li><li><strong>Part 4: Clustering Analysis</strong><ul style='list-style-type: disc; margin-left: 30px;'><li>K-Means with Elbow Plot</li><li>Hierarchical Clustering & Dendrogram</li><li>DBSCAN</li><li>Silhouette Analysis</li></ul></li><li><strong>Part 5: Dimensionality Reduction</strong><ul style='list-style-type: disc; margin-left: 30px;'><li>PCA & Biplot</li><li>t-SNE</li><li>UMAP</li><li>CA / MCA / MDS (as applicable)</li></ul></li><li><strong>Part 6: Interactive Visualizations</strong><ul style='list-style-type: disc; margin-left: 30px;'><li>Plotly Interactive Charts</li><li>Linked Views & Annotations</li></ul></li><li><strong>Part 7: Discussion & Conclusions</strong><ul style='list-style-type: disc; margin-left: 30px;'><li>Key Findings</li><li>Limitations & Future Work</li></ul></li><li><strong>Part 8: References</strong><ul style='list-style-type: disc; margin-left: 30px;'><li>Data Sources</li><li>Literature & Tools</li></ul></li><li><strong>Final Dashboard</strong><ul style='list-style-type: disc; margin-left: 30px;'><li>Tabbed Summary Dashboard</li></ul></li></ul>
# </div>

# %%
# ── Setup: Install and Import Required Libraries ──
# Uncomment the lines below if running in Colab and packages are not installed
# !pip install umap-learn prince plotly scikit-learn scipy

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go
import plotly.express as px
from plotly.subplots import make_subplots
from IPython.display import HTML, display

from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans, DBSCAN
from sklearn.metrics import silhouette_score, silhouette_samples
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from scipy.cluster.hierarchy import dendrogram, linkage

np.random.seed(42)
print("Libraries loaded successfully!")

# %% [markdown]
# <div style="background: linear-gradient(135deg, #4B2E83 0%, #32006E 100%); padding: 30px; border-radius: 10px; margin: 40px 0 30px 0; box-shadow: 0 5px 15px rgba(75,46,131,0.2);">
#   <h1 style="color: #FFF; font-family: 'Encode Sans', 'Arial', sans-serif; font-weight: 700; margin: 0; text-shadow: 2px 2px 4px rgba(0,0,0,0.3);">Part 1: Introduction &amp; Research Question</h1>
#   <p style="color: #E8D3FF; font-family: 'Encode Sans', 'Arial', sans-serif; font-size: 1.3em; margin: 10px 0; font-weight: 300;">Define your problem and motivate the analysis</p>
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h3 style="color: #4B2E83; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">Instructions</h3>
#   <p style="font-size: 1.05em; color: #555; line-height: 1.7;">In this section, clearly state your project's <strong>problem statement</strong>, the <strong>research questions</strong> you aim to answer, and <strong>why this analysis matters</strong>. Think about what patterns, groups, or structures you expect to find in your data and how advanced visualization techniques will help reveal them.</p>
# </div>

# %% [markdown]
# ### Problem Statement
#
# *[Describe the real-world problem or domain you are investigating. What is the context? Why is it important?]*
#
#
#
# ### Research Questions
#
# 1. *[State your primary research question]*
# 2. *[State your secondary research question(s)]*
# 3. *[Add more as needed]*
#
# ### Hypotheses
#
# - *[What patterns or clusters do you expect to find?]*
# - *[Which dimensionality reduction technique do you think will be most effective and why?]*
#
# ### Motivation & Relevance
#
# *[Explain why this project is relevant. Who benefits from this analysis? What decisions can it inform?]*

# %% [markdown]
# <div style="background-color: #FFF3E0; border-left: 4px solid #F57C00; padding: 15px 20px; margin: 20px 0; border-radius: 5px;">
#   <h3 style="color: #F57C00; margin-top: 0;">Deliverables — Part 1</h3>
#   <ul style="font-size: 1.05em; color: #555; line-height: 1.7;"><li>A clear problem statement (2–3 sentences)</li><li>At least 2 research questions</li><li>At least 2 hypotheses about expected patterns</li><li>A brief motivation paragraph (3–5 sentences)</li></ul>
# </div>

# %% [markdown]
# <div style="background: linear-gradient(135deg, #4B2E83 0%, #32006E 100%); padding: 30px; border-radius: 10px; margin: 40px 0 30px 0; box-shadow: 0 5px 15px rgba(75,46,131,0.2);">
#   <h1 style="color: #FFF; font-family: 'Encode Sans', 'Arial', sans-serif; font-weight: 700; margin: 0; text-shadow: 2px 2px 4px rgba(0,0,0,0.3);">Part 2: Data Description &amp; Preprocessing</h1>
#   <p style="color: #E8D3FF; font-family: 'Encode Sans', 'Arial', sans-serif; font-size: 1.3em; margin: 10px 0; font-weight: 300;">Load, inspect, clean, and prepare your dataset</p>
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h3 style="color: #4B2E83; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">Instructions</h3>
#   <p style="font-size: 1.05em; color: #555; line-height: 1.7;">Load your dataset and perform initial inspection. Check its shape, data types, and summary statistics. Handle missing values appropriately (imputation, removal, etc.). If needed, engineer new features. Finally, standardize numerical features using <code>StandardScaler</code> so that clustering and dimensionality reduction methods work correctly.</p>
# </div>

# %%
# ── 2.1 Load your dataset ──
# Replace the path below with your own data source
# Examples:
#   df = pd.read_csv('your_data.csv')
#   df = pd.read_csv('https://url-to-your-data.csv')
#   from sklearn.datasets import load_iris; df = pd.DataFrame(...)

# YOUR CODE HERE
# df = pd.read_csv('your_data.csv')

# Inspect shape and first rows
# print(f"Dataset shape: {df.shape[0]} rows x {df.shape[1]} columns")
# df.head()

# %%
# ── 2.2 Data types and basic info ──
# YOUR CODE HERE
# df.info()
# df.dtypes.value_counts()

# %%
# ── 2.3 Check and handle missing values ──
# YOUR CODE HERE

# Check missing values per column
# missing = df.isnull().sum()
# missing_pct = (missing / len(df)) * 100
# missing_report = pd.DataFrame({'Missing': missing, 'Percent': missing_pct})
# missing_report = missing_report[missing_report['Missing'] > 0].sort_values('Percent', ascending=False)
# print(missing_report)

# Handle missing values (choose your strategy)
# Option A: Drop rows with missing values
# df = df.dropna()

# Option B: Impute with median (numerical) or mode (categorical)
# from sklearn.impute import SimpleImputer
# num_cols = df.select_dtypes(include=[np.number]).columns
# cat_cols = df.select_dtypes(include=['object', 'category']).columns
# df[num_cols] = SimpleImputer(strategy='median').fit_transform(df[num_cols])
# df[cat_cols] = SimpleImputer(strategy='most_frequent').fit_transform(df[cat_cols])

# %%
# ── 2.4 Feature selection and standardization ──
# YOUR CODE HERE

# Select numerical features for analysis
# features = df.select_dtypes(include=[np.number]).columns.tolist()
# print(f"Numerical features ({len(features)}): {features}")

# Standardize
# scaler = StandardScaler()
# X_scaled = scaler.fit_transform(df[features])
# X_scaled = pd.DataFrame(X_scaled, columns=features)
# print(f"Scaled data shape: {X_scaled.shape}")
# X_scaled.describe().round(2)

# %% [markdown]
# <div style="background-color: #FFF3E0; border-left: 4px solid #F57C00; padding: 15px 20px; margin: 20px 0; border-radius: 5px;">
#   <h3 style="color: #F57C00; margin-top: 0;">Deliverables — Part 2</h3>
#   <ul style="font-size: 1.05em; color: #555; line-height: 1.7;"><li>Dataset loaded and shape reported</li><li>Data types summarized</li><li>Missing values identified and handled (with justification)</li><li>Numerical features standardized using StandardScaler</li><li>A brief written description of the dataset (what each row/column represents)</li></ul>
# </div>

# %% [markdown]
# <div style="background: linear-gradient(135deg, #4B2E83 0%, #32006E 100%); padding: 30px; border-radius: 10px; margin: 40px 0 30px 0; box-shadow: 0 5px 15px rgba(75,46,131,0.2);">
#   <h1 style="color: #FFF; font-family: 'Encode Sans', 'Arial', sans-serif; font-weight: 700; margin: 0; text-shadow: 2px 2px 4px rgba(0,0,0,0.3);">Part 3: Exploratory Data Analysis</h1>
#   <p style="color: #E8D3FF; font-family: 'Encode Sans', 'Arial', sans-serif; font-size: 1.3em; margin: 10px 0; font-weight: 300;">Understand your data before modeling</p>
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h3 style="color: #4B2E83; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">Instructions</h3>
#   <p style="font-size: 1.05em; color: #555; line-height: 1.7;">Before applying any clustering or dimensionality reduction, explore your data thoroughly. Compute <strong>descriptive statistics</strong>, visualize <strong>distributions</strong> of key variables, and create a <strong>correlation heatmap</strong> to understand relationships between features. This step informs which techniques and parameters to use later.</p>
# </div>

# %%
# ── 3.1 Descriptive statistics ──
# YOUR CODE HERE
# df.describe().round(2)

# %%
# ── 3.2 Distribution plots ──
# Plot histograms or box plots for each numerical feature
# YOUR CODE HERE

# Example: Histogram grid using plotly
# fig = make_subplots(
#     rows=2, cols=3,
#     subplot_titles=features[:6]  # Adjust based on number of features
# )
# for i, col in enumerate(features[:6]):
#     row = i // 3 + 1
#     col_idx = i % 3 + 1
#     fig.add_trace(
#         go.Histogram(x=df[col], name=col,
#                      marker_color='#4B2E83', opacity=0.7),
#         row=row, col=col_idx
#     )
# fig.update_layout(
#     title='<b>Feature Distributions</b>',
#     template='plotly_white', height=500, showlegend=False,
#     font=dict(family='Encode Sans, Arial, sans-serif')
# )
# fig.show()

# %%
# ── 3.3 Correlation heatmap ──
# YOUR CODE HERE

# corr = df[features].corr()
# fig = go.Figure(go.Heatmap(
#     z=corr.values,
#     x=corr.columns,
#     y=corr.columns,
#     colorscale=[[0, '#32006E'], [0.5, '#FFFFFF'], [1, '#E8B923']],
#     text=np.round(corr.values, 2),
#     texttemplate='%{text}',
#     textfont=dict(size=10),
#     zmin=-1, zmax=1
# ))
# fig.update_layout(
#     title='<b>Correlation Heatmap</b>',
#     template='plotly_white', height=600, width=700,
#     font=dict(family='Encode Sans, Arial, sans-serif')
# )
# fig.show()

# %% [markdown]
# <div style="background-color: #FFF3E0; border-left: 4px solid #F57C00; padding: 15px 20px; margin: 20px 0; border-radius: 5px;">
#   <h3 style="color: #F57C00; margin-top: 0;">Deliverables — Part 3</h3>
#   <ul style="font-size: 1.05em; color: #555; line-height: 1.7;"><li>Descriptive statistics table</li><li>At least 3 distribution plots (histograms, boxplots, or violin plots)</li><li>A correlation heatmap with annotations</li><li>2–3 sentences interpreting the key patterns you observe</li></ul>
# </div>

# %% [markdown]
# <div style="background: linear-gradient(135deg, #4B2E83 0%, #32006E 100%); padding: 30px; border-radius: 10px; margin: 40px 0 30px 0; box-shadow: 0 5px 15px rgba(75,46,131,0.2);">
#   <h1 style="color: #FFF; font-family: 'Encode Sans', 'Arial', sans-serif; font-weight: 700; margin: 0; text-shadow: 2px 2px 4px rgba(0,0,0,0.3);">Part 4: Clustering Analysis</h1>
#   <p style="color: #E8D3FF; font-family: 'Encode Sans', 'Arial', sans-serif; font-size: 1.3em; margin: 10px 0; font-weight: 300;">Discover natural groupings in your data</p>
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h3 style="color: #4B2E83; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">Instructions</h3>
#   <p style="font-size: 1.05em; color: #555; line-height: 1.7;">Apply multiple clustering algorithms to your standardized data. Use the <strong>elbow method</strong> and <strong>silhouette analysis</strong> to determine the optimal number of clusters for K-Means. Compare results with <strong>hierarchical clustering</strong> (dendrogram) and <strong>DBSCAN</strong>. Discuss which method works best for your data and why.</p>
# </div>

# %%
# ── 4.1 K-Means: Elbow method ──
# YOUR CODE HERE

# K_range = range(2, 11)
# inertias = []
# sil_scores = []
#
# for k in K_range:
#     km = KMeans(n_clusters=k, random_state=42, n_init=10)
#     km.fit(X_scaled)
#     inertias.append(km.inertia_)
#     sil_scores.append(silhouette_score(X_scaled, km.labels_))
#
# # Elbow plot
# fig = make_subplots(rows=1, cols=2,
#     subplot_titles=['<b>Elbow Method</b>', '<b>Silhouette Score</b>'])
#
# fig.add_trace(go.Scatter(
#     x=list(K_range), y=inertias, mode='lines+markers',
#     marker=dict(size=10, color='#4B2E83'),
#     line=dict(color='#4B2E83', width=3), name='Inertia'
# ), row=1, col=1)
#
# fig.add_trace(go.Scatter(
#     x=list(K_range), y=sil_scores, mode='lines+markers',
#     marker=dict(size=10, color='#E8B923'),
#     line=dict(color='#E8B923', width=3), name='Silhouette'
# ), row=1, col=2)
#
# fig.update_layout(
#     template='plotly_white', height=400,
#     font=dict(family='Encode Sans, Arial, sans-serif')
# )
# fig.update_xaxes(title_text='Number of Clusters (k)', row=1, col=1)
# fig.update_xaxes(title_text='Number of Clusters (k)', row=1, col=2)
# fig.update_yaxes(title_text='Inertia (WCSS)', row=1, col=1)
# fig.update_yaxes(title_text='Silhouette Score', row=1, col=2)
# fig.show()

# %%
# ── 4.2 K-Means: Fit with optimal k ──
# YOUR CODE HERE

# optimal_k = 3  # Replace with your chosen k from the elbow plot
# km_final = KMeans(n_clusters=optimal_k, random_state=42, n_init=10)
# df['cluster_kmeans'] = km_final.fit_predict(X_scaled)
#
# print(f"Optimal k = {optimal_k}")
# print(f"Silhouette score = {silhouette_score(X_scaled, df['cluster_kmeans']):.4f}")
# print(f"\nCluster sizes:")
# print(df['cluster_kmeans'].value_counts().sort_index())

# %%
# ── 4.3 Hierarchical clustering: Dendrogram ──
# YOUR CODE HERE

# Z = linkage(X_scaled, method='ward')
#
# fig, ax = plt.subplots(figsize=(14, 6))
# dendrogram(Z, truncate_mode='lastp', p=30,
#            leaf_font_size=10, ax=ax,
#            color_threshold=0.7 * max(Z[:, 2]))
# ax.set_title('Hierarchical Clustering Dendrogram (Ward)', fontsize=16, fontweight='bold')
# ax.set_xlabel('Sample Index (or Cluster Size)')
# ax.set_ylabel('Distance')
# plt.tight_layout()
# plt.show()

# %%
# ── 4.4 DBSCAN ──
# YOUR CODE HERE

# from sklearn.neighbors import NearestNeighbors
#
# # Find a good eps using k-distance graph
# k = 5
# nn = NearestNeighbors(n_neighbors=k)
# nn.fit(X_scaled)
# distances, _ = nn.kneighbors(X_scaled)
# k_dists = np.sort(distances[:, -1])
#
# fig = go.Figure(go.Scatter(
#     x=list(range(len(k_dists))), y=k_dists,
#     mode='lines', line=dict(color='#4B2E83', width=2)))
# fig.update_layout(
#     title=f'<b>k-Distance Graph</b> (k={k}) — Look for the elbow',
#     xaxis_title='Points (sorted)', yaxis_title=f'{k}-th Nearest Neighbor Distance',
#     template='plotly_white', height=400,
#     font=dict(family='Encode Sans, Arial, sans-serif'))
# fig.show()
#
# # Fit DBSCAN
# eps_val = 1.0   # Adjust based on k-distance graph
# min_samples = 5  # Adjust as needed
# db = DBSCAN(eps=eps_val, min_samples=min_samples)
# df['cluster_dbscan'] = db.fit_predict(X_scaled)
#
# n_clusters_db = len(set(df['cluster_dbscan'])) - (1 if -1 in df['cluster_dbscan'].values else 0)
# n_noise = (df['cluster_dbscan'] == -1).sum()
# print(f"DBSCAN found {n_clusters_db} clusters and {n_noise} noise points")

# %%
# ── 4.5 Silhouette analysis (detailed) ──
# YOUR CODE HERE

# sample_sil = silhouette_samples(X_scaled, df['cluster_kmeans'])
# avg_sil = silhouette_score(X_scaled, df['cluster_kmeans'])
#
# fig = go.Figure()
# y_lower = 0
# for i in range(optimal_k):
#     cluster_sil = np.sort(sample_sil[df['cluster_kmeans'] == i])
#     cluster_size = len(cluster_sil)
#     y_upper = y_lower + cluster_size
#     fig.add_trace(go.Bar(
#         x=cluster_sil, y=list(range(y_lower, y_upper)),
#         orientation='h', name=f'Cluster {i}',
#         marker_color=['#4B2E83','#E8B923','#22D3A5','#E8608A','#4F8EF7','#F57C00'][i % 6]
#     ))
#     y_lower = y_upper
#
# fig.add_vline(x=avg_sil, line_dash='dash', line_color='red',
#               annotation_text=f'Avg: {avg_sil:.3f}')
# fig.update_layout(
#     title='<b>Silhouette Plot</b> — K-Means Clustering',
#     xaxis_title='Silhouette Coefficient', yaxis_title='Sample Index',
#     template='plotly_white', height=500, showlegend=True,
#     font=dict(family='Encode Sans, Arial, sans-serif'))
# fig.show()

# %% [markdown]
# <div style="background-color: #FFF3E0; border-left: 4px solid #F57C00; padding: 15px 20px; margin: 20px 0; border-radius: 5px;">
#   <h3 style="color: #F57C00; margin-top: 0;">Deliverables — Part 4</h3>
#   <ul style="font-size: 1.05em; color: #555; line-height: 1.7;"><li>Elbow plot and silhouette score plot for K-Means</li><li>K-Means results with chosen k and cluster sizes</li><li>Hierarchical clustering dendrogram</li><li>DBSCAN with k-distance graph and results (clusters found, noise points)</li><li>Silhouette analysis plot</li><li>A written comparison: which clustering method best fits your data and why?</li></ul>
# </div>

# %% [markdown]
# <div style="background: linear-gradient(135deg, #4B2E83 0%, #32006E 100%); padding: 30px; border-radius: 10px; margin: 40px 0 30px 0; box-shadow: 0 5px 15px rgba(75,46,131,0.2);">
#   <h1 style="color: #FFF; font-family: 'Encode Sans', 'Arial', sans-serif; font-weight: 700; margin: 0; text-shadow: 2px 2px 4px rgba(0,0,0,0.3);">Part 5: Dimensionality Reduction</h1>
#   <p style="color: #E8D3FF; font-family: 'Encode Sans', 'Arial', sans-serif; font-size: 1.3em; margin: 10px 0; font-weight: 300;">Visualize high-dimensional structure in 2D</p>
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h3 style="color: #4B2E83; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">Instructions</h3>
#   <p style="font-size: 1.05em; color: #555; line-height: 1.7;">Apply at least three dimensionality reduction techniques to project your data into 2D. Start with <strong>PCA</strong> (linear, interpretable) and create a biplot. Then use <strong>t-SNE</strong> (nonlinear, local structure) and <strong>UMAP</strong> (nonlinear, global + local). Color points by your cluster assignments to see if the low-dimensional projections agree with the clusters. If your data has categorical variables, consider <strong>CA/MCA</strong>; if you have a distance/dissimilarity matrix, try <strong>MDS</strong>.</p>
# </div>

# %%
# ── 5.1 PCA: Explained variance and biplot ──
# YOUR CODE HERE

# pca = PCA()
# pca_result = pca.fit_transform(X_scaled)
#
# # Scree plot
# exp_var = pca.explained_variance_ratio_
# cum_var = np.cumsum(exp_var)
#
# fig = go.Figure()
# fig.add_trace(go.Bar(
#     x=[f'PC{i+1}' for i in range(len(exp_var))],
#     y=exp_var, name='Individual',
#     marker_color='#4B2E83', opacity=0.7))
# fig.add_trace(go.Scatter(
#     x=[f'PC{i+1}' for i in range(len(cum_var))],
#     y=cum_var, name='Cumulative',
#     mode='lines+markers', marker=dict(color='#E8B923'),
#     line=dict(color='#E8B923', width=3)))
# fig.add_hline(y=0.80, line_dash='dash', line_color='#C62828',
#               annotation_text='80% threshold')
# fig.update_layout(
#     title='<b>PCA Scree Plot</b> — Explained Variance',
#     xaxis_title='Principal Component', yaxis_title='Variance Explained',
#     template='plotly_white', height=400,
#     font=dict(family='Encode Sans, Arial, sans-serif'))
# fig.show()
#
# print(f"PC1 explains {exp_var[0]:.1%}, PC2 explains {exp_var[1]:.1%}")
# print(f"Cumulative (PC1+PC2): {cum_var[1]:.1%}")

# %%
# ── 5.2 PCA Biplot ──
# YOUR CODE HERE

# fig = go.Figure()
#
# # Scatter of observations colored by cluster
# for c in range(optimal_k):
#     mask = df['cluster_kmeans'] == c
#     fig.add_trace(go.Scatter(
#         x=pca_result[mask, 0], y=pca_result[mask, 1],
#         mode='markers', name=f'Cluster {c}',
#         marker=dict(size=7, opacity=0.7,
#             color=['#4B2E83','#E8B923','#22D3A5','#E8608A','#4F8EF7','#F57C00'][c % 6])))
#
# # Loading vectors
# loadings = pca.components_[:2].T  # (n_features, 2)
# scale = max(abs(pca_result[:, :2]).max()) / max(abs(loadings).max()) * 0.8
# for i, feat in enumerate(features):
#     fig.add_annotation(
#         ax=0, ay=0, x=loadings[i, 0]*scale, y=loadings[i, 1]*scale,
#         xref='x', yref='y', axref='x', ayref='y',
#         showarrow=True, arrowhead=2, arrowsize=1.5,
#         arrowcolor='#C62828', font=dict(color='#C62828', size=10),
#         text=feat)
#
# fig.update_layout(
#     title='<b>PCA Biplot</b> — Observations + Feature Loadings',
#     xaxis_title=f'PC1 ({exp_var[0]:.1%})',
#     yaxis_title=f'PC2 ({exp_var[1]:.1%})',
#     template='plotly_white', height=600, width=700,
#     font=dict(family='Encode Sans, Arial, sans-serif'))
# fig.show()

# %%
# ── 5.3 t-SNE ──
# YOUR CODE HERE

# tsne = TSNE(n_components=2, perplexity=30, random_state=42, n_iter=1000)
# tsne_result = tsne.fit_transform(X_scaled)
#
# fig = go.Figure()
# for c in range(optimal_k):
#     mask = df['cluster_kmeans'] == c
#     fig.add_trace(go.Scatter(
#         x=tsne_result[mask, 0], y=tsne_result[mask, 1],
#         mode='markers', name=f'Cluster {c}',
#         marker=dict(size=7, opacity=0.7,
#             color=['#4B2E83','#E8B923','#22D3A5','#E8608A','#4F8EF7','#F57C00'][c % 6])))
#
# fig.update_layout(
#     title='<b>t-SNE Projection</b> (perplexity=30)',
#     xaxis_title='t-SNE 1', yaxis_title='t-SNE 2',
#     template='plotly_white', height=550, width=650,
#     font=dict(family='Encode Sans, Arial, sans-serif'))
# fig.show()

# %%
# ── 5.4 UMAP ──
# YOUR CODE HERE

# import umap
#
# reducer = umap.UMAP(n_components=2, n_neighbors=15, min_dist=0.1, random_state=42)
# umap_result = reducer.fit_transform(X_scaled)
#
# fig = go.Figure()
# for c in range(optimal_k):
#     mask = df['cluster_kmeans'] == c
#     fig.add_trace(go.Scatter(
#         x=umap_result[mask, 0], y=umap_result[mask, 1],
#         mode='markers', name=f'Cluster {c}',
#         marker=dict(size=7, opacity=0.7,
#             color=['#4B2E83','#E8B923','#22D3A5','#E8608A','#4F8EF7','#F57C00'][c % 6])))
#
# fig.update_layout(
#     title='<b>UMAP Projection</b> (n_neighbors=15, min_dist=0.1)',
#     xaxis_title='UMAP 1', yaxis_title='UMAP 2',
#     template='plotly_white', height=550, width=650,
#     font=dict(family='Encode Sans, Arial, sans-serif'))
# fig.show()

# %%
# ── 5.5 Additional: CA / MCA / MDS (choose as applicable) ──
# YOUR CODE HERE
#
# If you have categorical data, use Correspondence Analysis (CA) or
# Multiple Correspondence Analysis (MCA):
#   import prince
#   mca = prince.MCA(n_components=2)
#   mca_result = mca.fit_transform(df_categorical)
#
# If you have a distance/dissimilarity matrix, use MDS:
#   from sklearn.manifold import MDS
#   mds = MDS(n_components=2, dissimilarity='precomputed', random_state=42)
#   mds_result = mds.fit_transform(distance_matrix)
#
# Visualize below:
# ...

# %% [markdown]
# <div style="background-color: #FFF3E0; border-left: 4px solid #F57C00; padding: 15px 20px; margin: 20px 0; border-radius: 5px;">
#   <h3 style="color: #F57C00; margin-top: 0;">Deliverables — Part 5</h3>
#   <ul style="font-size: 1.05em; color: #555; line-height: 1.7;"><li>PCA scree plot with 80% variance threshold marked</li><li>PCA biplot with loadings and cluster coloring</li><li>t-SNE 2D scatter plot colored by clusters</li><li>UMAP 2D scatter plot colored by clusters</li><li>(Optional) CA/MCA or MDS projection if applicable</li><li>A written comparison: how do the projections differ? Which best reveals your data's structure?</li></ul>
# </div>

# %% [markdown]
# <div style="background: linear-gradient(135deg, #4B2E83 0%, #32006E 100%); padding: 30px; border-radius: 10px; margin: 40px 0 30px 0; box-shadow: 0 5px 15px rgba(75,46,131,0.2);">
#   <h1 style="color: #FFF; font-family: 'Encode Sans', 'Arial', sans-serif; font-weight: 700; margin: 0; text-shadow: 2px 2px 4px rgba(0,0,0,0.3);">Part 6: Interactive Visualizations</h1>
#   <p style="color: #E8D3FF; font-family: 'Encode Sans', 'Arial', sans-serif; font-size: 1.3em; margin: 10px 0; font-weight: 300;">Build rich, interactive charts with Plotly</p>
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h3 style="color: #4B2E83; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">Instructions</h3>
#   <p style="font-size: 1.05em; color: #555; line-height: 1.7;">Create at least <strong>two interactive Plotly visualizations</strong> that go beyond the standard plots above. Ideas include: <strong>3D scatter plots</strong> (PCA or UMAP in 3D), <strong>parallel coordinates</strong> colored by cluster, <strong>animated scatter</strong> (e.g., varying perplexity for t-SNE), <strong>interactive heatmaps</strong> with hover info, or <strong>linked views</strong>. These charts should help tell the story of your data and highlight the key findings from your analysis.</p>
# </div>

# %%
# ── 6.1 Interactive visualization #1 ──
# Example: Parallel coordinates plot
# YOUR CODE HERE

# fig = go.Figure(go.Parcoords(
#     line=dict(
#         color=df['cluster_kmeans'],
#         colorscale=[[0,'#4B2E83'],[0.5,'#E8B923'],[1,'#22D3A5']],
#         showscale=True
#     ),
#     dimensions=[
#         dict(label=col, values=df[col]) for col in features
#     ] + [dict(label='Cluster', values=df['cluster_kmeans'])]
# ))
# fig.update_layout(
#     title='<b>Parallel Coordinates</b> — Features by Cluster',
#     template='plotly_white', height=500,
#     font=dict(family='Encode Sans, Arial, sans-serif'))
# fig.show()

# %%
# ── 6.2 Interactive visualization #2 ──
# Example: 3D PCA scatter
# YOUR CODE HERE

# pca_3d = PCA(n_components=3)
# pca_3d_result = pca_3d.fit_transform(X_scaled)
#
# fig = go.Figure(go.Scatter3d(
#     x=pca_3d_result[:, 0],
#     y=pca_3d_result[:, 1],
#     z=pca_3d_result[:, 2],
#     mode='markers',
#     marker=dict(
#         size=4, opacity=0.7,
#         color=df['cluster_kmeans'],
#         colorscale=[[0,'#4B2E83'],[0.5,'#E8B923'],[1,'#22D3A5']],
#         showscale=True
#     )
# ))
# fig.update_layout(
#     title='<b>3D PCA Projection</b>',
#     scene=dict(
#         xaxis_title=f'PC1 ({pca_3d.explained_variance_ratio_[0]:.1%})',
#         yaxis_title=f'PC2 ({pca_3d.explained_variance_ratio_[1]:.1%})',
#         zaxis_title=f'PC3 ({pca_3d.explained_variance_ratio_[2]:.1%})'
#     ),
#     template='plotly_white', height=600,
#     font=dict(family='Encode Sans, Arial, sans-serif'))
# fig.show()

# %%
# ── 6.3 Additional interactive visualizations ──
# YOUR CODE HERE
# Add more interactive charts as needed to support your analysis

# %% [markdown]
# <div style="background-color: #FFF3E0; border-left: 4px solid #F57C00; padding: 15px 20px; margin: 20px 0; border-radius: 5px;">
#   <h3 style="color: #F57C00; margin-top: 0;">Deliverables — Part 6</h3>
#   <ul style="font-size: 1.05em; color: #555; line-height: 1.7;"><li>At least 2 interactive Plotly visualizations (beyond basic scatter/histogram)</li><li>Each chart should have a clear title, axis labels, and legend</li><li>A brief caption under each chart explaining what it reveals</li></ul>
# </div>

# %% [markdown]
# <div style="background: linear-gradient(135deg, #4B2E83 0%, #32006E 100%); padding: 30px; border-radius: 10px; margin: 40px 0 30px 0; box-shadow: 0 5px 15px rgba(75,46,131,0.2);">
#   <h1 style="color: #FFF; font-family: 'Encode Sans', 'Arial', sans-serif; font-weight: 700; margin: 0; text-shadow: 2px 2px 4px rgba(0,0,0,0.3);">Part 7: Discussion &amp; Conclusions</h1>
#   <p style="color: #E8D3FF; font-family: 'Encode Sans', 'Arial', sans-serif; font-size: 1.3em; margin: 10px 0; font-weight: 300;">Interpret your results and reflect</p>
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h3 style="color: #4B2E83; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">Instructions</h3>
#   <p style="font-size: 1.05em; color: #555; line-height: 1.7;">Synthesize your findings across all sections. Revisit your original research questions and hypotheses. Discuss what the clustering revealed, how the dimensionality reduction projections compare, and what the interactive visualizations highlighted. Be honest about <strong>limitations</strong> and suggest <strong>future work</strong>.</p>
# </div>

# %% [markdown]
# ### Key Findings
#
# 1. *[What did your clustering analysis reveal? How many natural groups exist?]*
# 2. *[Which dimensionality reduction technique best captured your data's structure? Why?]*
# 3. *[What relationships or patterns did the interactive visualizations highlight?]*
# 4. *[Were your initial hypotheses supported or contradicted?]*
#
# ### Comparison of Methods
#
# *[Compare the clustering methods (K-Means vs. Hierarchical vs. DBSCAN). Compare the dimensionality reduction methods (PCA vs. t-SNE vs. UMAP). Which combinations worked best?]*
#
# ### Limitations
#
# - *[What are the limitations of your dataset (sample size, missing data, bias)?]*
# - *[What are the limitations of the methods you used?]*
# - *[What assumptions did you make that might not hold?]*
#
# ### Future Work
#
# - *[How could this analysis be extended or improved?]*
# - *[What additional data would strengthen the analysis?]*
# - *[What other techniques could be applied?]*

# %% [markdown]
# <div style="background-color: #FFF3E0; border-left: 4px solid #F57C00; padding: 15px 20px; margin: 20px 0; border-radius: 5px;">
#   <h3 style="color: #F57C00; margin-top: 0;">Deliverables — Part 7</h3>
#   <ul style="font-size: 1.05em; color: #555; line-height: 1.7;"><li>At least 4 key findings, each supported by evidence from your analysis</li><li>A methods comparison paragraph</li><li>At least 3 limitations acknowledged</li><li>At least 2 future work directions</li></ul>
# </div>

# %% [markdown]
# <div style="background: linear-gradient(135deg, #4B2E83 0%, #32006E 100%); padding: 30px; border-radius: 10px; margin: 40px 0 30px 0; box-shadow: 0 5px 15px rgba(75,46,131,0.2);">
#   <h1 style="color: #FFF; font-family: 'Encode Sans', 'Arial', sans-serif; font-weight: 700; margin: 0; text-shadow: 2px 2px 4px rgba(0,0,0,0.3);">Part 8: References</h1>
#   <p style="color: #E8D3FF; font-family: 'Encode Sans', 'Arial', sans-serif; font-size: 1.3em; margin: 10px 0; font-weight: 300;">Cite your sources</p>
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h3 style="color: #4B2E83; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">Instructions</h3>
#   <p style="font-size: 1.05em; color: #555; line-height: 1.7;">List all data sources, academic references, and tools used. Use a consistent citation format (APA, IEEE, or similar). Include links to datasets and documentation for any libraries you relied on.</p>
# </div>

# %% [markdown]
# ### Data Sources
#
# 1. *[Dataset name, URL, and description]*
# 2. *[Dataset name, URL, and description]*
#
# ### Literature
#
# 1. *[Author(s). (Year). Title. Journal/Conference. DOI/URL]*
# 2. *[Author(s). (Year). Title. Journal/Conference. DOI/URL]*
#
# ### Tools & Libraries
#
# - Python 3.x — https://www.python.org/
# - NumPy — https://numpy.org/
# - pandas — https://pandas.pydata.org/
# - scikit-learn — https://scikit-learn.org/
# - Plotly — https://plotly.com/python/
# - UMAP — https://umap-learn.readthedocs.io/
# - *[Add other libraries you used]*

# %% [markdown]
# <div style="background-color: #FFF3E0; border-left: 4px solid #F57C00; padding: 15px 20px; margin: 20px 0; border-radius: 5px;">
#   <h3 style="color: #F57C00; margin-top: 0;">Deliverables — Part 8</h3>
#   <ul style="font-size: 1.05em; color: #555; line-height: 1.7;"><li>All data sources cited with URLs</li><li>At least 2 academic/technical references</li><li>All libraries and tools listed</li></ul>
# </div>

# %% [markdown]
# <div style="background: linear-gradient(135deg, #4B2E83 0%, #32006E 100%); padding: 30px; border-radius: 10px; margin: 40px 0 30px 0; box-shadow: 0 5px 15px rgba(75,46,131,0.2);">
#   <h1 style="color: #FFF; font-family: 'Encode Sans', 'Arial', sans-serif; font-weight: 700; margin: 0; text-shadow: 2px 2px 4px rgba(0,0,0,0.3);">Final Dashboard</h1>
#   <p style="color: #E8D3FF; font-family: 'Encode Sans', 'Arial', sans-serif; font-size: 1.3em; margin: 10px 0; font-weight: 300;">Tabbed summary of your project findings</p>
# </div>

# %% [markdown]
# <div style="border-left: 5px solid #4B2E83; background-color: #F9F7FC; padding: 20px 25px; margin: 20px 0; border-radius: 5px;">
#   <h3 style="color: #4B2E83; font-family: 'Encode Sans', 'Arial', sans-serif; margin-top: 0;">Instructions</h3>
#   <p style="font-size: 1.05em; color: #555; line-height: 1.7;">Build an interactive tabbed dashboard that summarizes your entire project. The template below provides the full dark-theme CSS/JS scaffolding — replace the placeholder figures with your actual results. Organize your best visualizations across the tabs to tell a cohesive story: <strong>EDA</strong> (key distributions and correlations), <strong>Clustering</strong> (best clustering result and silhouette), <strong>Dim. Reduction</strong> (PCA/t-SNE/UMAP comparison), and <strong>Insights</strong> (your most impactful interactive chart and KPI summary).</p>
# </div>

# %%
# ============================================================
#  APPLIED PROJECT DASHBOARD TEMPLATE
# ============================================================
# Replace the placeholder figures below with your actual results.
# The CSS/JS scaffolding is ready — just swap in your plotly figures.
# ============================================================
import plotly.graph_objects as go
from plotly.subplots import make_subplots
from IPython.display import HTML, display
import numpy as np

np.random.seed(42)

# ── Dark Theme ──
C = {
    "bg": "#0F1117", "card": "#171A23", "grid": "#262B3A",
    "text": "#E8EAF0", "muted": "#8B90A0",
    "primary": "#4B2E83", "accent": "#E8B923",
    "green": "#22D3A5", "pink": "#E8608A",
    "palette": ["#4B2E83","#E8B923","#22D3A5","#E8608A","#4F8EF7","#F57C00"]
}
BASE = dict(paper_bgcolor=C["card"], plot_bgcolor=C["card"],
            font=dict(family="Inter, Segoe UI, sans-serif", color=C["text"], size=12),
            margin=dict(l=55, r=30, t=60, b=45))

def style(fig):
    fig.update_xaxes(gridcolor=C["grid"], zerolinecolor=C["grid"], tickfont=dict(color=C["muted"]))
    fig.update_yaxes(gridcolor=C["grid"], zerolinecolor=C["grid"], tickfont=dict(color=C["muted"]))
    return fig

figs = {}

# ============================================================
# TAB 1: EDA — Replace these placeholder figures
# ============================================================

# Placeholder KPI row (replace values with your actual metrics)
f = make_subplots(rows=1, cols=4, specs=[[{"type":"indicator"}]*4], horizontal_spacing=0.05)
for i, (label, val) in enumerate([
    ("Observations", 1000), ("Features", 12),
    ("Missing %", 2.3), ("Clusters", 3)
], 1):
    f.add_trace(go.Indicator(mode="number", value=val,
        number=dict(valueformat=".0f" if val == int(val) else ".1f",
                    font=dict(size=36, color=C["text"])),
        title=dict(text=f"<span style='color:{C['muted']};font-size:14px'>{label}</span>")), 1, i)
f.update_layout(**BASE, height=160)
figs["kpi"] = f

# Placeholder distribution chart (replace with your actual histogram)
f = go.Figure(go.Histogram(
    x=np.random.randn(500), nbinsx=40,
    marker_color=C["primary"], opacity=0.8))
f.update_layout(**BASE, height=380,
    title=dict(text="<b>Feature Distribution</b> — Replace with your data", font=dict(size=16)))
style(f)
figs["dist"] = f

# Placeholder correlation heatmap (replace with your actual correlation matrix)
np.random.seed(42)
placeholder_corr = np.corrcoef(np.random.randn(5, 100))
placeholder_labels = [f"Feat {i+1}" for i in range(5)]
f = go.Figure(go.Heatmap(
    z=placeholder_corr, x=placeholder_labels, y=placeholder_labels,
    colorscale=[[0,"#171A23"],[0.5,"#4B2E83"],[1,"#E8B923"]],
    text=np.round(placeholder_corr, 2), texttemplate="%{text}", textfont=dict(size=11),
    zmin=-1, zmax=1))
f.update_layout(**BASE, height=420,
    title=dict(text="<b>Correlation Heatmap</b> — Replace with your data", font=dict(size=16)))
figs["corr"] = f

# ============================================================
# TAB 2: Clustering — Replace these placeholder figures
# ============================================================

# Placeholder elbow plot
k_range = range(2, 11)
placeholder_inertias = [1000 / k**0.8 for k in k_range]
f = go.Figure(go.Scatter(
    x=list(k_range), y=placeholder_inertias, mode='lines+markers',
    marker=dict(size=10, color=C["accent"]),
    line=dict(color=C["accent"], width=3)))
f.update_layout(**BASE, height=380,
    title=dict(text="<b>Elbow Method</b> — Replace with your data", font=dict(size=16)),
    xaxis_title="k", yaxis_title="Inertia")
style(f)
figs["elbow"] = f

# Placeholder cluster scatter
np.random.seed(42)
f = go.Figure()
for c in range(3):
    x = np.random.randn(50) + c * 3
    y = np.random.randn(50) + c * 2
    f.add_trace(go.Scatter(x=x, y=y, mode='markers',
        name=f'Cluster {c}',
        marker=dict(size=8, opacity=0.7, color=C["palette"][c])))
f.update_layout(**BASE, height=420,
    title=dict(text="<b>Cluster Scatter</b> — Replace with your PCA/UMAP projection", font=dict(size=16)),
    xaxis_title="Dim 1", yaxis_title="Dim 2")
style(f)
figs["clusters"] = f

# ============================================================
# TAB 3: Dimensionality Reduction — Replace these placeholder figures
# ============================================================

# Placeholder PCA projection
np.random.seed(42)
f = go.Figure()
for c in range(3):
    x = np.random.randn(50) + c * 2
    y = np.random.randn(50) + c * 1.5
    f.add_trace(go.Scatter(x=x, y=y, mode='markers',
        name=f'Cluster {c}',
        marker=dict(size=7, opacity=0.7, color=C["palette"][c])))
f.update_layout(**BASE, height=420,
    title=dict(text="<b>PCA Projection</b> — Replace with your data", font=dict(size=16)),
    xaxis_title="PC1", yaxis_title="PC2")
style(f)
figs["pca"] = f

# Placeholder t-SNE projection
np.random.seed(123)
f = go.Figure()
for c in range(3):
    x = np.random.randn(50) * 5 + c * 15
    y = np.random.randn(50) * 5 + c * 10
    f.add_trace(go.Scatter(x=x, y=y, mode='markers',
        name=f'Cluster {c}',
        marker=dict(size=7, opacity=0.7, color=C["palette"][c])))
f.update_layout(**BASE, height=420,
    title=dict(text="<b>t-SNE Projection</b> — Replace with your data", font=dict(size=16)),
    xaxis_title="t-SNE 1", yaxis_title="t-SNE 2")
style(f)
figs["tsne"] = f

# ============================================================
# TAB 4: Insights — Replace these placeholder figures
# ============================================================

# Placeholder insight KPIs
f = make_subplots(rows=1, cols=3, specs=[[{"type":"indicator"}]*3], horizontal_spacing=0.05)
for i, (label, val, fmt) in enumerate([
    ("Best Silhouette", 0.62, ".2f"),
    ("PCA Var (2D)", 78.4, ".1f"),
    ("DBSCAN Noise %", 5.2, ".1f")
], 1):
    f.add_trace(go.Indicator(mode="number", value=val,
        number=dict(valueformat=fmt, font=dict(size=36, color=C["text"])),
        title=dict(text=f"<span style='color:{C['muted']};font-size:14px'>{label}</span>")), 1, i)
f.update_layout(**BASE, height=160)
figs["insight_kpi"] = f

# Placeholder interactive chart
np.random.seed(42)
dimensions = [
    dict(label=f"Feature {i+1}", values=np.random.randn(100) * (i+1))
    for i in range(5)
]
f = go.Figure(go.Parcoords(
    line=dict(color=np.random.randint(0, 3, 100),
              colorscale=[[0,C["palette"][0]],[0.5,C["palette"][1]],[1,C["palette"][2]]]),
    dimensions=dimensions))
f.update_layout(**BASE, height=420,
    title=dict(text="<b>Parallel Coordinates</b> — Replace with your data", font=dict(size=16)))
figs["parcoords"] = f

# ============================================================
# Assemble the tabbed dashboard
# ============================================================
def div(key, first=False):
    return figs[key].to_html(full_html=False,
        include_plotlyjs="cdn" if first else False,
        config={"displayModeBar": True, "displaylogo": False})

card = lambda inner: f"<div class='card'>{inner}</div>"

tabs = {
    "EDA": card(div("kpi", first=True)) + card(div("dist")) + card(div("corr")),
    "Clustering": card(div("elbow")) + card(div("clusters")),
    "Dim. Reduction": card(div("pca")) + card(div("tsne")),
    "Insights": card(div("insight_kpi")) + card(div("parcoords")),
}

nav = "".join(
    f"<button class='tab-btn{' active' if i==0 else ''}' "
    f"onclick=\"showTab(event,'tab{i}')\">{name}</button>"
    for i, name in enumerate(tabs)
)
panels = "".join(
    f"<div id='tab{i}' class='tab-panel' "
    f"style='display:{'block' if i==0 else 'none'}'>{c}</div>"
    for i, c in enumerate(tabs.values())
)

html = f"""<div id="dash"><style>
  #dash {{background:{C['bg']};border-radius:14px;padding:22px;font-family:Inter,'Segoe UI',sans-serif;}}
  #dash .dash-header {{display:flex;justify-content:space-between;align-items:baseline;margin-bottom:16px;}}
  #dash h1 {{color:{C['text']};font-size:21px;margin:0;}}
  #dash .sub {{color:{C['muted']};font-size:12px;}}
  #dash .tab-bar {{display:flex;gap:6px;border-bottom:1px solid {C['grid']};margin-bottom:18px;}}
  #dash .tab-btn {{background:none;border:none;color:{C['muted']};padding:10px 18px;font-size:13.5px;font-weight:600;cursor:pointer;border-bottom:2.5px solid transparent;}}
  #dash .tab-btn:hover {{color:{C['text']};}}
  #dash .tab-btn.active {{color:{C['accent']};border-bottom-color:{C['accent']};}}
  #dash .card {{background:{C['card']};border:1px solid {C['grid']};border-radius:12px;padding:6px;margin-bottom:16px;box-shadow:0 2px 10px rgba(0,0,0,.35);}}
</style>
<div class="dash-header"><h1>Applied Project Dashboard</h1><span class="sub">BDATA 412 · Section 8</span></div>
<div class="tab-bar">{nav}</div>{panels}
<script>function showTab(evt,id){{const d=document.getElementById('dash');d.querySelectorAll('.tab-panel').forEach(p=>p.style.display='none');d.querySelectorAll('.tab-btn').forEach(b=>b.classList.remove('active'));document.getElementById(id).style.display='block';evt.currentTarget.classList.add('active');document.getElementById(id).querySelectorAll('.js-plotly-plot').forEach(g=>Plotly.Plots.resize(g));}}</script></div>"""
display(HTML(html))
print("Dashboard ready — switch tabs to explore EDA, Clustering, Dim. Reduction, and Insights.")
print("Replace the placeholder figures above with your actual project results!")
